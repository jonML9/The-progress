# %% [markdown]
# # Covariance and correlation

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Doing correlation by hand

# %%
def de_mean(x):
    xmean = np.mean(x)
    return [xi - xmean for xi in x]

def covariance(x, y):
    n = len(x)
    return np.dot(de_mean(x), de_mean(y)) / (n - 1)

pageSpeeds = np.random.normal(3, 10, 1000)
purchaseAmount = np.random.normal(4, 20, 1000)

plt.scatter(pageSpeeds, purchaseAmount)

covariance(pageSpeeds, purchaseAmount)
# Out:
# np.float64(6.989475275036317)

# %% [markdown]
# ## And with numpy

# %%
np.corrcoef(pageSpeeds, purchaseAmount)
# Out:
# array([[1.        , 0.03551465],
#        [0.03551465, 1.        ]])

# %% [markdown]
# ## Covariance with numpy

# %%
np.cov(pageSpeeds, purchaseAmount)
# Out:
# array([[105.18635301,   6.98947528],
#        [  6.98947528, 368.22612903]])
